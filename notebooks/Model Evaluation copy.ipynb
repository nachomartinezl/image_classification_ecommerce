# %% [markdown]
# # Vehicle Classification
#
# ## Evaluate your model

# %%
import os

from sklearn.metrics import accuracy_score, classification_report

from utils import utils
from models import resnet_50

# %% [markdown]
# ## Experiment settings
#
# Set here the two variables in the following way:
#
# - **CONFIG_YML:** assign the path to the config.yml file used for the experiment you want to evaluate
# - **WEIGHTS:** assign the path to the model weights (.h5 file) you want to evaluate

# %%
# Modify this
CONFIG_YML = "../experiments/exp_008/config.yml"
WEIGHTS = "../experiments/exp_008/model.11-0.5774.h5"

# %%
# (!) Don't touch this cell, will load the config file specified before
config = utils.load_config(CONFIG_YML)
config
# Out:
# {'seed': 123,
#  'data': {'directory': '/home/app/src/data/car_ims_v1/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': '/home/app/src/experiments/exp_002/model.12-3.8985.h5',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.4,
#   'data_aug_layer': {'random_flip': {'mode': 'horizontal_and_vertical'},
#    'random_rotation': {'factor': 0.2},
#    'random_zoom': {'height_factor': 0.2, 'width_factor': 0.2}}},
#  'compile': {'optimizer': {'adam': {'learning_rate': 3e-05}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 100,
#   'callbacks': {'early_stopping': {'monitor': 'val_accuracy',
#     'patience': 5,
#     'restore_best_weights': True},
#    'model_checkpoint': {'filepath': '/home/app/src/experiments/exp_008/model.{epoch:02d}-{val_accuracy:.4f}.h5',
#     'save_best_only': True},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/exp_008/logs'}}}}

# %%
# (!) Don't touch this cell, will use the config file to infer the class names
#     and also to load the corresponding testing dataset.
#     If you get an error, you must review your data/code.

MODEL_CLASSES = utils.get_class_names(config)

if len(MODEL_CLASSES) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your data!"
    )

_dirname, _ = os.path.split(config['data']['directory'])
TEST_FOLDER = os.path.join(_dirname, 'test')

if not os.path.exists(TEST_FOLDER):
    raise ValueError("'test' folder not found!")
    
if len(os.listdir(TEST_FOLDER)) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your testing dataset!"
    )
    
if set(os.listdir(TEST_FOLDER)) != set(MODEL_CLASSES):
    raise ValueError(
        "The name of the subfolders inside your test set "
        "doesn't match with the model classes!"
    )

# %% [markdown]
# ## Load your model
#
# Use `resnet_50.create_model()` and remember to properly setup the model weights!
#
# Assign the model to the variable `cnn_model`.

# %%
# Complete this
# TODO
cnn_model = resnet_50.create_model(weights=WEIGHTS)

# It should print your model correctly
print(cnn_model.summary())
# Out:
# 2022-11-16 16:26:09.949540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:09.958503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:09.959347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:09.961295: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 16:26:09.961795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:09.962711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:09.963639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:10.604844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:10.605750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:10.606578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 16:26:10.607328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10794 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 196)               401604
#
# =================================================================
# Total params: 23,989,316
# Trainable params: 23,936,196
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %% [markdown]
# ## Get predictions from testing dataset

# %%
# (!) Don't touch this cell, will use the loaded model and
#     the function utils.predict_from_folder() to get 
#     model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions, labels = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions) != len(labels):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )
# Out:
# 2022-11-16 16:26:16.161537: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-11-16 16:26:16.437834: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-16 16:26:16.438788: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-16 16:26:16.438900: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-16 16:26:16.439624: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-16 16:26:16.439746: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.

# %%
# (!) Don't touch this cell

print(classification_report(y_true=labels, y_pred=predictions))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.74      0.89      0.80        44
#                              Acura Integra Type R 2001       0.55      0.50      0.52        44
#                                    Acura RL Sedan 2012       0.56      0.16      0.24        32
#                                    Acura TL Sedan 2012       0.57      0.63      0.60        43
#                                   Acura TL Type-S 2008       0.71      0.40      0.52        42
#                                   Acura TSX Sedan 2012       0.67      0.10      0.17        40
#                               Acura ZDX Hatchback 2012       0.55      0.28      0.37        39
#               Aston Martin V8 Vantage Convertible 2012       0.49      0.51      0.50        45
#                     Aston Martin V8 Vantage Coupe 2012       0.56      0.24      0.34        41
#                   Aston Martin Virage Convertible 2012       0.58      0.33      0.42        33
#                         Aston Martin Virage Coupe 2012       0.84      0.55      0.67        38
#                                    Audi 100 Sedan 1994       0.50      0.10      0.17        40
#                                    Audi 100 Wagon 1994       0.60      0.36      0.45        42
#                                     Audi A5 Coupe 2012       0.82      0.34      0.48        41
#                                     Audi R8 Coupe 2012       0.64      0.37      0.47        43
#                             Audi RS 4 Convertible 2008       0.62      0.50      0.55        36
#                                     Audi S4 Sedan 2007       0.17      0.67      0.28        45
#                                     Audi S4 Sedan 2012       0.19      0.41      0.26        39
#                               Audi S5 Convertible 2012       0.76      0.38      0.51        42
#                                     Audi S5 Coupe 2012       0.19      0.12      0.15        42
#                                     Audi S6 Sedan 2011       0.53      0.17      0.26        46
#                                 Audi TT Hatchback 2011       0.22      0.23      0.22        40
#                                  Audi TT RS Coupe 2012       0.35      0.67      0.46        39
#                                    Audi TTS Coupe 2012       0.42      0.24      0.30        42
#                                     Audi V8 Sedan 1994       0.37      0.53      0.44        43
#                          BMW 1 Series Convertible 2012       0.91      0.57      0.70        35
#                                BMW 1 Series Coupe 2012       0.70      0.51      0.59        41
#                                BMW 3 Series Sedan 2012       0.45      0.36      0.40        42
#                                BMW 3 Series Wagon 2012       0.51      0.61      0.56        41
#                          BMW 6 Series Convertible 2007       0.65      0.25      0.36        44
#                          BMW ActiveHybrid 5 Sedan 2012       0.92      0.32      0.48        34
#                                      BMW M3 Coupe 2012       0.62      0.36      0.46        44
#                                      BMW M5 Sedan 2010       0.43      0.54      0.48        41
#                                BMW M6 Convertible 2010       0.26      0.61      0.36        41
#                                        BMW X3 SUV 2012       0.62      0.53      0.57        38
#                                        BMW X5 SUV 2007       1.00      0.15      0.26        41
#                                        BMW X6 SUV 2012       0.57      0.57      0.57        42
#                                BMW Z4 Convertible 2012       0.52      0.42      0.47        40
#                              Bentley Arnage Sedan 2009       0.52      0.74      0.61        39
#             Bentley Continental Flying Spur Sedan 2007       0.53      0.45      0.49        44
#                      Bentley Continental GT Coupe 2007       0.47      0.30      0.37        46
#                      Bentley Continental GT Coupe 2012       0.83      0.15      0.25        34
# Bentley Continental Supersports Conv. Convertible 2012       0.47      0.72      0.57        36
#                            Bentley Mulsanne Sedan 2011       0.49      0.57      0.53        35
#                   Bugatti Veyron 16.4 Convertible 2009       0.48      0.81      0.60        32
#                         Bugatti Veyron 16.4 Coupe 2009       0.66      0.44      0.53        43
#                                 Buick Enclave SUV 2012       0.81      0.69      0.74        42
#                                 Buick Rainier SUV 2007       0.85      0.55      0.67        42
#                                    Buick Regal GS 2012       0.45      0.29      0.35        35
#                                Buick Verano Sedan 2012       0.59      0.54      0.56        37
#                              Cadillac CTS-V Sedan 2012       0.88      0.33      0.47        43
#                    Cadillac Escalade EXT Crew Cab 2007       0.78      0.64      0.70        44
#                                  Cadillac SRX SUV 2012       0.85      0.27      0.41        41
#                      Chevrolet Avalanche Crew Cab 2012       0.53      0.44      0.48        45
#                      Chevrolet Camaro Convertible 2012       0.90      0.41      0.56        44
#                               Chevrolet Cobalt SS 2010       0.56      0.54      0.55        41
#                    Chevrolet Corvette Convertible 2012       0.64      0.23      0.34        39
#        Chevrolet Corvette Ron Fellows Edition Z06 2007       0.87      0.54      0.67        37
#                            Chevrolet Corvette ZR1 2012       0.63      0.41      0.50        46
#                       Chevrolet Express Cargo Van 2007       0.36      0.34      0.35        29
#                             Chevrolet Express Van 2007       0.50      0.14      0.22        35
#                                  Chevrolet HHR SS 2010       0.96      0.67      0.79        36
#                            Chevrolet Impala Sedan 2007       0.58      0.35      0.43        43
#                     Chevrolet Malibu Hybrid Sedan 2010       0.73      0.29      0.42        38
#                            Chevrolet Malibu Sedan 2007       0.58      0.25      0.35        44
#                       Chevrolet Monte Carlo Coupe 2007       0.75      0.27      0.39        45
#     Chevrolet Silverado 1500 Classic Extended Cab 2007       0.84      0.50      0.63        42
#             Chevrolet Silverado 1500 Extended Cab 2012       0.41      0.28      0.33        43
#          Chevrolet Silverado 1500 Hybrid Crew Cab 2012       0.50      0.35      0.41        40
#              Chevrolet Silverado 1500 Regular Cab 2012       0.51      0.55      0.53        44
#            Chevrolet Silverado 2500HD Regular Cab 2012       0.63      0.32      0.42        38
#                             Chevrolet Sonic Sedan 2012       0.65      0.45      0.53        44
#                        Chevrolet Tahoe Hybrid SUV 2012       1.00      0.11      0.20        37
#                          Chevrolet TrailBlazer SS 2009       0.71      0.38      0.49        40
#                            Chevrolet Traverse SUV 2012       0.41      0.25      0.31        44
#                                Chrysler 300 SRT-8 2010       0.23      0.58      0.33        48
#                                Chrysler Aspen SUV 2009       0.94      0.37      0.53        43
#                    Chrysler Crossfire Convertible 2008       0.86      0.70      0.77        43
#                   Chrysler PT Cruiser Convertible 2008       0.66      0.91      0.77        45
#                      Chrysler Sebring Convertible 2010       0.71      0.68      0.69        40
#                 Chrysler Town and Country Minivan 2012       0.74      0.70      0.72        37
#                               Daewoo Nubira Wagon 2002       0.83      0.22      0.35        45
#                               Dodge Caliber Wagon 2007       0.65      0.31      0.42        42
#                               Dodge Caliber Wagon 2012       0.47      0.45      0.46        40
#                             Dodge Caravan Minivan 1997       0.74      0.91      0.81        43
#                             Dodge Challenger SRT8 2011       0.74      0.82      0.78        39
#                               Dodge Charger SRT-8 2009       0.57      0.31      0.40        42
#                               Dodge Charger Sedan 2012       0.20      0.59      0.29        41
#                             Dodge Dakota Club Cab 2007       0.43      0.71      0.53        38
#                             Dodge Dakota Crew Cab 2010       0.80      0.59      0.68        41
#                                 Dodge Durango SUV 2007       1.00      0.24      0.39        45
#                                 Dodge Durango SUV 2012       0.44      0.60      0.51        43
#                                 Dodge Journey SUV 2012       0.34      0.75      0.47        44
#                                Dodge Magnum Wagon 2008       0.64      0.53      0.58        40
#                    Dodge Ram Pickup 3500 Crew Cab 2010       0.59      0.90      0.72        42
#                    Dodge Ram Pickup 3500 Quad Cab 2009       0.81      0.39      0.52        44
#                          Dodge Sprinter Cargo Van 2009       1.00      0.36      0.53        39
#                             Eagle Talon Hatchback 1998       0.41      0.39      0.40        46
#                                   FIAT 500 Abarth 2012       0.59      0.96      0.73        27
#                              FIAT 500 Convertible 2012       0.83      0.76      0.79        33
#                    Ferrari 458 Italia Convertible 2012       0.56      0.26      0.35        39
#                          Ferrari 458 Italia Coupe 2012       0.39      0.57      0.46        42
#                    Ferrari California Convertible 2012       0.38      0.74      0.50        39
#                                  Ferrari FF Coupe 2012       0.88      0.69      0.77        42
#                                Fisker Karma Sedan 2012       0.94      0.40      0.56        43
#                           Ford E-Series Wagon Van 2012       0.81      0.78      0.79        37
#                                     Ford Edge SUV 2012       0.58      0.44      0.50        43
#                            Ford Expedition EL SUV 2009       0.91      0.66      0.76        44
#                            Ford F-150 Regular Cab 2007       0.51      0.62      0.56        45
#                            Ford F-150 Regular Cab 2012       0.55      0.79      0.65        42
#                    Ford F-450 Super Duty Crew Cab 2012       0.80      0.78      0.79        41
#                                 Ford Fiesta Sedan 2012       0.70      0.38      0.49        42
#                                  Ford Focus Sedan 2007       0.67      0.36      0.46        45
#                             Ford Freestar Minivan 2007       0.85      0.75      0.80        44
#                                     Ford GT Coupe 2006       0.40      0.69      0.50        45
#                          Ford Mustang Convertible 2007       0.65      0.45      0.53        44
#                              Ford Ranger SuperCab 2011       0.94      0.40      0.57        42
#                                    GMC Acadia SUV 2012       0.29      0.73      0.41        44
#                           GMC Canyon Extended Cab 2012       0.66      0.47      0.55        40
#                                    GMC Savana Van 2012       0.65      0.76      0.70        68
#                                   GMC Terrain SUV 2012       0.55      0.66      0.60        41
#                              GMC Yukon Hybrid SUV 2012       0.63      0.45      0.53        42
#                             Geo Metro Convertible 1993       1.00      0.52      0.69        44
#                            HUMMER H2 SUT Crew Cab 2009       0.77      0.47      0.58        43
#                               HUMMER H3T Crew Cab 2010       0.68      0.72      0.70        39
#                                Honda Accord Coupe 2012       0.67      0.31      0.42        39
#                                Honda Accord Sedan 2012       0.41      0.39      0.40        38
#                             Honda Odyssey Minivan 2007       0.47      0.63      0.54        41
#                             Honda Odyssey Minivan 2012       0.52      0.33      0.41        42
#                              Hyundai Accent Sedan 2012       0.38      0.58      0.46        24
#                               Hyundai Azera Sedan 2012       0.53      0.60      0.56        42
#                             Hyundai Elantra Sedan 2007       0.51      0.67      0.58        42
#                 Hyundai Elantra Touring Hatchback 2012       0.39      0.57      0.46        42
#                             Hyundai Genesis Sedan 2012       0.55      0.67      0.60        43
#                              Hyundai Santa Fe SUV 2012       0.93      0.60      0.72        42
#                       Hyundai Sonata Hybrid Sedan 2012       0.53      0.85      0.65        33
#                              Hyundai Sonata Sedan 2012       0.73      0.77      0.75        39
#                                Hyundai Tucson SUV 2012       0.42      0.70      0.52        43
#                        Hyundai Veloster Hatchback 2012       0.55      0.39      0.46        41
#                              Hyundai Veracruz SUV 2012       0.20      0.52      0.29        42
#                              Infiniti G Coupe IPL 2012       0.90      0.26      0.41        34
#                                 Infiniti QX56 SUV 2011       0.88      0.72      0.79        32
#                                Isuzu Ascender SUV 2008       0.88      0.57      0.70        40
#                                     Jaguar XK XKR 2012       0.29      0.57      0.38        46
#                                  Jeep Compass SUV 2012       0.62      0.60      0.61        42
#                           Jeep Grand Cherokee SUV 2012       0.46      0.60      0.52        45
#                                  Jeep Liberty SUV 2012       0.80      0.45      0.58        44
#                                  Jeep Patriot SUV 2012       0.75      0.55      0.63        44
#                                 Jeep Wrangler SUV 2012       0.92      0.77      0.84        43
#                       Lamborghini Aventador Coupe 2012       0.69      0.42      0.52        43
#                          Lamborghini Diablo Coupe 2001       0.66      0.61      0.64        44
#        Lamborghini Gallardo LP 570-4 Superleggera 2012       1.00      0.74      0.85        35
#                        Lamborghini Reventon Coupe 2008       0.76      0.72      0.74        36
#                                Land Rover LR2 SUV 2012       0.37      0.62      0.46        42
#                        Land Rover Range Rover SUV 2012       0.64      0.55      0.59        42
#                            Lincoln Town Car Sedan 2011       0.61      0.79      0.69        39
#                  MINI Cooper Roadster Convertible 2012       0.65      0.94      0.77        36
#                     Maybach Landaulet Convertible 2012       0.93      0.48      0.64        29
#                                 Mazda Tribute SUV 2011       0.94      0.42      0.58        36
#                             McLaren MP4-12C Coupe 2012       0.73      0.73      0.73        44
#               Mercedes-Benz 300-Class Convertible 1993       0.78      0.44      0.56        48
#                       Mercedes-Benz C-Class Sedan 2012       0.92      0.27      0.41        45
#                       Mercedes-Benz E-Class Sedan 2012       0.26      0.49      0.34        43
#                       Mercedes-Benz S-Class Sedan 2012       0.71      0.50      0.59        44
#                      Mercedes-Benz SL-Class Coupe 2009       0.64      0.50      0.56        36
#                        Mercedes-Benz Sprinter Van 2012       0.65      0.88      0.75        41
#                           Mitsubishi Lancer Sedan 2012       0.31      0.47      0.37        47
#                                Nissan 240SX Coupe 1998       0.91      0.43      0.59        46
#                             Nissan Juke Hatchback 2012       0.45      0.57      0.50        44
#                             Nissan Leaf Hatchback 2012       1.00      0.71      0.83        42
#                           Nissan NV Passenger Van 2012       0.73      0.87      0.80        38
#                               Plymouth Neon Coupe 1999       1.00      0.70      0.83        44
#                            Porsche Panamera Sedan 2012       0.46      0.63      0.53        43
#                         Ram C-V Cargo Van Minivan 2012       0.67      0.71      0.69        41
#                           Rolls-Royce Ghost Sedan 2012       0.46      0.68      0.55        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.59      0.63      0.61        30
#                         Rolls-Royce Phantom Sedan 2012       0.73      0.25      0.37        44
#                                Scion xD Hatchback 2012       0.38      0.15      0.21        41
#                             Spyker C8 Convertible 2009       0.58      0.73      0.65        45
#                                   Spyker C8 Coupe 2009       0.71      0.29      0.41        42
#                                Suzuki Aerio Sedan 2007       0.68      0.50      0.58        38
#                              Suzuki Kizashi Sedan 2012       0.18      0.63      0.28        46
#                              Suzuki SX4 Hatchback 2012       0.12      0.74      0.20        42
#                                  Suzuki SX4 Sedan 2012       0.41      0.17      0.25        40
#                               Tesla Model S Sedan 2012       0.72      0.55      0.63        38
#                                Toyota 4Runner SUV 2012       0.68      0.57      0.62        40
#                                Toyota Camry Sedan 2012       0.20      0.63      0.31        43
#                              Toyota Corolla Sedan 2012       0.56      0.35      0.43        43
#                                Toyota Sequoia SUV 2012       0.89      0.66      0.76        38
#                       Volkswagen Beetle Hatchback 2012       0.71      0.71      0.71        42
#                         Volkswagen Golf Hatchback 1991       0.50      0.83      0.62        46
#                         Volkswagen Golf Hatchback 2012       0.77      0.47      0.58        43
#                                   Volvo 240 Sedan 1993       0.56      0.73      0.63        45
#                               Volvo C30 Hatchback 2012       0.50      0.80      0.62        41
#                                    Volvo XC90 SUV 2007       0.23      0.74      0.36        43
#                          smart fortwo Convertible 2012       0.71      0.68      0.69        40
#
#                                               accuracy                           0.52      8041
#                                              macro avg       0.62      0.52      0.53      8041
#                                           weighted avg       0.62      0.52      0.52      8041

# %%
# (!) Don't touch this cell

acc = accuracy_score(y_true=labels, y_pred=predictions)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.5185!
